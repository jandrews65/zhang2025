# %% [markdown]
# # Zhang (2025) Reproduction - Data Exploration
#
# Exploratory analysis of GDELT data, sentiment scores, and market data.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
