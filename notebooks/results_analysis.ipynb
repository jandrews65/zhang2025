# %% [markdown]
# # Zhang (2025) Reproduction - Results Analysis
#
# Analysis of model performance, SHAP interpretability, and backtest results.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
